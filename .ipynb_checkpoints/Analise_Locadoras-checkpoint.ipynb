# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /Users/juliam/opt/anaconda3/lib/python3.7/site-packages (from selenium) (1.25.8)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /Users/juliam/opt/anaconda3/lib/python3.7/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /Users/juliam/opt/anaconda3/lib/python3.7/site-packages (from BeautifulSoup4) (1.9.5)

# %%
import numpy as np
import pandas as pd
import pandas_datareader
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
# %matplotlib inline
import selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
#1 vamos importar as informações das ações de 3 empresas Locadoras: Localiza, Movida e Unidas
start= datetime.datetime(2014,1,1)
end= datetime.datetime(2020,1,1)

# %%
localiza= web.DataReader("RENT3.SA", 'yahoo', start, end)

# %%
localiza.head()
# Out:
#                 High      Low      Open     Close     Volume  Adj Close
# Date
# 2014-01-02  10.12850  9.83522  10.10430   9.90174  5147131.0   7.572349
# 2014-01-03  10.10430  9.89267   9.89267  10.09830  5378325.0   7.722667
# 2014-01-06  10.12850  9.84732  10.08010   9.88964  4918583.0   7.563096
# 2014-01-07  10.00760  9.79592   9.96825   9.82313  2836181.0   7.512234
# 2014-01-08   9.94709  9.66893   9.80196   9.85639  2890755.0   7.537666

# %%
movida = web.DataReader("MOVI3.SA", 'yahoo', start, end)
unidas = web.DataReader("LCAM3.SA", 'yahoo', start, end)

# %%
movida.head()
# Out:
#                High      Low     Open    Close     Volume  Adj Close
# Date
# 2017-05-24  9.05270  8.41951  8.46898  8.97355  1892221.0   8.341428
# 2017-05-25  9.38909  8.85483  8.98345  9.00323   993464.0   8.369018
# 2017-05-26  9.25057  8.78557  9.00323  8.82515  2187056.0   8.203481
# 2017-05-29  8.82515  8.82515  8.82515  8.82515        0.0   8.203481
# 2017-05-30  9.33962  9.07249  9.15164  9.15164   937266.0   8.506971

# %%
unidas.head()
# Out:
#                High      Low     Open    Close    Volume  Adj Close
# Date
# 2014-01-02  2.33333  2.23333  2.27000  2.33333  105600.0   0.975933
# 2014-01-03  2.32333  2.27333  2.27333  2.27333   29400.0   0.950837
# 2014-01-06  2.33333  2.17000  2.33333  2.17333  206100.0   0.909012
# 2014-01-07  2.23333  2.18667  2.20667  2.20000   51600.0   0.920167
# 2014-01-08  2.20000  2.16333  2.20000  2.17000  288600.0   0.907619

# %%
# agora vamos analisar os preços 'Open'de todas elas:
localiza['Open'].plot(label= 'Localiza', figsize=(16,8))
movida['Open'].plot(label= 'Movida')
unidas['Open'].plot(label= 'Unidas')
plt.legend()

# %%
# agora vamos plotar o volume de ações tradado por dia de cada uma:
localiza['Volume'].plot(label= 'Localiza', figsize= (16,8))
movida['Volume'].plot(label='Movida')
unidas['Volume'].plot(label= 'Unidas')
plt.legend()

# %%
localiza['Volume'].argmax()
# Out:
# 228

# %%
# agora vamos tentar plotar um gráfico dos custos de captação (bolha) de cada empresa, para enxergar quem capta mais barato.
driver= webdriver.Chrome(executable_path='./chromedriver')

emissor=[]
montante=[]
remuneracao=[]
data_emissao=[]
driver.get("https://ri.localiza.com/mercado-de-capitais/dividas")

# %%
table = driver.find_element_by_tag_name('table')

# %%
table.screenshot('tt.png')
# Out:
# True

# %%
body = table.find_element_by_tag_name('tbody')

# %%
body
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="92223f2e-42a0-4bcc-8ebb-3e012b3be4a7")>

# %%
rows = body.find_elements_by_tag_name('tr')

# %%
rows
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="4b57a23a-4e8a-4ad5-88d2-43248908a021")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="7eec686d-9093-4f0e-8008-9bb31eda16fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="2af26666-40ab-41a3-a338-2e43586661e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="31cd95d6-f75a-4ccf-a3e7-7f8cf7e28abf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="976fc519-5ae1-470b-893f-78b33c3bbd55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="d905bcc2-afad-44ba-8f98-d1626d15fbc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="30b29cc1-4e6d-44b1-aad1-50187491e003")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="ca7f70dd-bf20-401e-9ddf-d455830f92db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="d6c11b90-970b-4521-91f7-358d96d30b71")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="fabede73-84e9-420a-80f5-4789b0299682")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="86f880bb-bb1d-4659-8d46-20a7caed5c4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="f5c66738-2d39-4ecd-bcde-996322635898")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="c56bb34f-605d-4809-a5e9-da8d1541f66e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="71f989b3-e877-48d6-9192-5aae2d662a8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="9758e67e-3d7d-4bbc-9bd2-883c749d78bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="2845d3bf-2325-4b6a-a277-5d94f1ea7785")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="1a66f399-fb9f-4a24-8e14-cb05154985a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="2255c4e9-3c46-4be8-825c-38705418129c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="4f275ac0-eb16-4516-989d-cd8b3939ccf3")>]

# %%
lista = []

for row in rows:
    
    try:
        cells = row.find_elements_by_tag_name('td')
        name = cells[0].get_attribute('innerHTML')
        amount = cells[2].get_attribute('innerHTML')
        rate= cells[3].get_attribute('innerHTML')
        date= cells[4].get_attribute('innerHTML')
        
        d= {'name': name, 'amount': amount, 'rate': rate, 'date': date}
        lista.append(d)
        
    except:
        print('error')
# Out:
# error
# error

# %%
df = pd.DataFrame(lista)

# %%
df
# Out:
#                                   name    amount         rate        date
# 0             Localiza Rent a Car S.A.    500,00  111,50% CDI  12/12/2016
# 1             Localiza Rent a Car S.A.    700,00  107,25% CDI  15/05/2017
# 2             Localiza Rent a Car S.A.    868,90  109,35% CDI  15/12/2017
# 3             Localiza Rent a Car S.A.    216,10  111,30% CDI  15/12/2017
# 4             Localiza Rent a Car S.A.    200,00  107,90% CDI  18/09/2018
# 5             Localiza Rent a Car S.A.    800,00  112,32% CDI  18/09/2018
# 6             Localiza Rent a Car S.A.  1.000,00  107,25% CDI  15/04/2019
# 7             Localiza Rent a Car S.A.  1.000,00  CDI + 1,05%  29/11/2019
# 8                  Localiza Fleet S.A.    300,00  112,00% CDI  18/07/2018
# 9                  Localiza Fleet S.A.    400,00  110,40% CDI  21/12/2018
# 10                 Localiza Fleet S.A.    300,00  109,00% CDI  29/07/2019
# 11                 Localiza Fleet S.A.    999,90  CDI + 1,00%  12/02/2020
# 12            Localiza Rent a Car S.A.    500,00  108,00% CDI  24/09/2019
# 13  Rental Brasil Adm. E Participações    370,00   99,00% CDI  26/02/2018

# %%
emissor=[]
montante=[]
remuneracao=[]
data_emissao=[]
driver.get("https://ri.unidas.com.br/acoes-e-debentures/debentures-e-notas-promissorias/")

# %%
table = driver.find_element_by_tag_name('table')

# %%
table
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="13a9345f-91d9-4e33-b32d-268f50266d3a")>

# %%
body = table.find_element_by_tag_name('tbody')

# %%
body
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a58fa2e21c93d5132fdcb58f9a9394fa", element="20049d66-ffe5-4354-9270-ae0e16595de5")>

# %%
rows = body.find_elements_by_tag_name('tr')

# %%
[i for i in range(1,10)]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lista_unidas = []

for row in rows:
    
    try:
        cells = row.find_elements_by_tag_name('td')
        name = cells[0].find_element_by_tag_name('span').get_attribute('innerHTML')
        amount = cells[2].find_element_by_tag_name('span').get_attribute('innerHTML')
        rate= cells[3].find_element_by_tag_name('span').get_attribute('innerHTML')
        date= cells[5].find_element_by_tag_name('span').get_attribute('innerHTML')
        
        d= {'name': name, 'amount': amount, 'rate': rate, 'date': date}
        lista_unidas.append(d)
        
    except:
        print('error')

# %%
df_unidas= pd.DataFrame(lista_unidas[1:])

# %%
df_unidas
# Out:
#                                           name   amount           rate  \
# 0                                       Unidas    100,0    CDI + 1,75%
# 1                                       Unidas    150,0    CDI + 2,20%
# 2                                       Unidas    250,0    CDI + 1,40%
# 3                                       Unidas    100,0    CDI + 1,20%
# 4                                       Unidas    411,4    CDI + 1,40%
# 5                                       Unidas    350,0    119% do CDI
# 6                                       Unidas    400,0    113% do CDI
# 7   Unidas<br>\n(Cia. de Locação das Américas)    200.0    108% do CDI
# 8                                       Unidas    150,0    CDI + 1,40%
# 9                                   Auto Ricci    300,0    CDI + 2,10%
# 10                                 Unidas S.A.     70,0    CDI + 3,00%
# 11                                 Unidas S.A.    300,0    CDI + 2,70%
# 12                                 Unidas S.A.     80,0    CDI + 1,20%
# 13                                 Unidas S.A.    500,0  117,5% do CDI
# 14                                 Unidas S.A.    150,0  110,6% do CDI
# 15                                 Unidas S.A.  1.000,0  107,9% do CDI
# 16                                 Unidas S.A.    200,0  109,7% do CDI
# 17                                 Unidas S.A.      4,0    CDI + 2,20%
#
#           date
# 0   29/10/2013
# 1   23/06/2017
# 2   28/08/2017
# 3   17/11/2017
# 4   19/02/2018
# 5   27/04/2018
# 6   27/09/2018
# 7   20/09/2019
# 8   29/11/2017
# 9   22/06/2017
# 10  20/06/2016
# 11  07/04/2017
# 12  29/09/2017
# 13  29/03/2018
# 14  15/09/2018
# 15  10/04/2019
# 16  18/11/2019
# 17  03/03/2017

# %%
df_unidas.iloc[7]['name'] = 'Unidas'

# %%
df_unidas['amount'] = pd.to_numeric(df_unidas['amount'].apply(lambda x: x.replace('.', '').replace(',', '.')))

# %%
df_unidas['date'] = pd.to_datetime(df_unidas['date'], format="%d/%m/%Y")

# %%
df_unidas
# Out:
#            name  amount           rate       date
# 0        Unidas   100.0    CDI + 1,75% 2013-10-29
# 1        Unidas   150.0    CDI + 2,20% 2017-06-23
# 2        Unidas   250.0    CDI + 1,40% 2017-08-28
# 3        Unidas   100.0    CDI + 1,20% 2017-11-17
# 4        Unidas   411.4    CDI + 1,40% 2018-02-19
# 5        Unidas   350.0    119% do CDI 2018-04-27
# 6        Unidas   400.0    113% do CDI 2018-09-27
# 7        Unidas  2000.0    108% do CDI 2019-09-20
# 8        Unidas   150.0    CDI + 1,40% 2017-11-29
# 9    Auto Ricci   300.0    CDI + 2,10% 2017-06-22
# 10  Unidas S.A.    70.0    CDI + 3,00% 2016-06-20
# 11  Unidas S.A.   300.0    CDI + 2,70% 2017-04-07
# 12  Unidas S.A.    80.0    CDI + 1,20% 2017-09-29
# 13  Unidas S.A.   500.0  117,5% do CDI 2018-03-29
# 14  Unidas S.A.   150.0  110,6% do CDI 2018-09-15
# 15  Unidas S.A.  1000.0  107,9% do CDI 2019-04-10
# 16  Unidas S.A.   200.0  109,7% do CDI 2019-11-18
# 17  Unidas S.A.     4.0    CDI + 2,20% 2017-03-03

# %%
'108% do CDI'.split(' ')[0][:-1].replace('.','').replace(',','.')
# Out:
# '108'

# %%
'CDI + 1,20%'.split(' ')[-1][:-1].replace('.','').replace(',','.')
# Out:
# '1.20'

# %%
def parse_cdi(value):
    if value.startswith('CDI'):
        return value.split(' ')[-1][:-1].replace('.','').replace(',','.')
    else:
        return value.split(' ')[0][:-1].replace('.','').replace(',','.')

# %%
df_unidas['true_rate'] = df_unidas['rate'].apply(parse_cdi)

# %%
df_unidas
# Out:
#            name  amount           rate       date true_rate
# 0        Unidas   100.0    CDI + 1,75% 2013-10-29      1.75
# 1        Unidas   150.0    CDI + 2,20% 2017-06-23      2.20
# 2        Unidas   250.0    CDI + 1,40% 2017-08-28      1.40
# 3        Unidas   100.0    CDI + 1,20% 2017-11-17      1.20
# 4        Unidas   411.4    CDI + 1,40% 2018-02-19      1.40
# 5        Unidas   350.0    119% do CDI 2018-04-27       119
# 6        Unidas   400.0    113% do CDI 2018-09-27       113
# 7        Unidas  2000.0    108% do CDI 2019-09-20       108
# 8        Unidas   150.0    CDI + 1,40% 2017-11-29      1.40
# 9    Auto Ricci   300.0    CDI + 2,10% 2017-06-22      2.10
# 10  Unidas S.A.    70.0    CDI + 3,00% 2016-06-20      3.00
# 11  Unidas S.A.   300.0    CDI + 2,70% 2017-04-07      2.70
# 12  Unidas S.A.    80.0    CDI + 1,20% 2017-09-29      1.20
# 13  Unidas S.A.   500.0  117,5% do CDI 2018-03-29     117.5
# 14  Unidas S.A.   150.0  110,6% do CDI 2018-09-15     110.6
# 15  Unidas S.A.  1000.0  107,9% do CDI 2019-04-10     107.9
# 16  Unidas S.A.   200.0  109,7% do CDI 2019-11-18     109.7
# 17  Unidas S.A.     4.0    CDI + 2,20% 2017-03-03      2.20

# %%
cdi = pd.read_csv('taxa_selic_apurada.csv', ';', header= 1)

# %%
cdi= cdi.dropna(axis=1)

# %%
cdi
# Out:
#             Data Taxa (% a.a.) Fator diário     Financeiro (R$)  Operações  \
# 0     20/05/2020           2,9   1,00011345  797.609.833.052,45        935
# 1     19/05/2020           2,9   1,00011345  786.622.171.085,08        956
# 2     18/05/2020           2,9   1,00011345  788.953.337.732,54        926
# 3     15/05/2020           2,9   1,00011345  793.484.776.829,85        938
# 4     14/05/2020           2,9   1,00011345  788.590.595.939,14        943
# ...          ...           ...          ...                 ...        ...
# 2501  07/06/2010           9,4   1,00035657                   0          0
# 2502  04/06/2010           9,4   1,00035657                   0          0
# 2503  02/06/2010           9,4   1,00035657                   0          0
# 2504  01/06/2010           9,4   1,00035657                   0          0
# 2505  31/05/2010          9,39   1,00035621                   0          0
#
#      Média Mediana Moda Desvio padrão Índice de curtose
# 0      2,9    2,89  2,9          0,02           493,099
# 1      2,9    2,89  2,9         0,018           562,331
# 2      2,9    2,89  2,9         0,017             599,4
# 3      2,9    2,89  2,9          0,02           503,904
# 4      2,9    2,89  2,9         0,018            544,47
# ...    ...     ...  ...           ...               ...
# 2501     0       0    0             0                 0
# 2502     0       0    0             0                 0
# 2503     0       0    0             0                 0
# 2504     0       0    0             0                 0
# 2505     0       0    0             0                 0
#
# [2506 rows x 10 columns]

# %%
cdi['Data']= pd.to_datetime(cdi['Data'], format= "%d/%m/%Y")

# %%
cdi['Taxa (% a.a.)'] = pd.to_numeric(cdi['Taxa (% a.a.)'].apply(lambda x: x.replace(',', '.')))

# %%
cdi
# Out:
#            Data  Taxa (% a.a.) Fator diário     Financeiro (R$)  Operações  \
# 0    2020-05-20           2.90   1,00011345  797.609.833.052,45        935
# 1    2020-05-19           2.90   1,00011345  786.622.171.085,08        956
# 2    2020-05-18           2.90   1,00011345  788.953.337.732,54        926
# 3    2020-05-15           2.90   1,00011345  793.484.776.829,85        938
# 4    2020-05-14           2.90   1,00011345  788.590.595.939,14        943
# ...         ...            ...          ...                 ...        ...
# 2501 2010-06-07           9.40   1,00035657                   0          0
# 2502 2010-06-04           9.40   1,00035657                   0          0
# 2503 2010-06-02           9.40   1,00035657                   0          0
# 2504 2010-06-01           9.40   1,00035657                   0          0
# 2505 2010-05-31           9.39   1,00035621                   0          0
#
#      Média Mediana Moda Desvio padrão Índice de curtose       Date
# 0      2,9    2,89  2,9          0,02           493,099 2020-05-20
# 1      2,9    2,89  2,9         0,018           562,331 2020-05-19
# 2      2,9    2,89  2,9         0,017             599,4 2020-05-18
# 3      2,9    2,89  2,9          0,02           503,904 2020-05-15
# 4      2,9    2,89  2,9         0,018            544,47 2020-05-14
# ...    ...     ...  ...           ...               ...        ...
# 2501     0       0    0             0                 0 2010-06-07
# 2502     0       0    0             0                 0 2010-06-04
# 2503     0       0    0             0                 0 2010-06-02
# 2504     0       0    0             0                 0 2010-06-01
# 2505     0       0    0             0                 0 2010-05-31
#
# [2506 rows x 11 columns]

# %%
df['date']= pd.to_datetime(df['date'],format="%d/%m/%Y" )

# %%
df_unidas
# Out:
#            name  amount           rate       date true_rate
# 0        Unidas   100.0    CDI + 1,75% 2013-10-29      1.75
# 1        Unidas   150.0    CDI + 2,20% 2017-06-23      2.20
# 2        Unidas   250.0    CDI + 1,40% 2017-08-28      1.40
# 3        Unidas   100.0    CDI + 1,20% 2017-11-17      1.20
# 4        Unidas   411.4    CDI + 1,40% 2018-02-19      1.40
# 5        Unidas   350.0    119% do CDI 2018-04-27       119
# 6        Unidas   400.0    113% do CDI 2018-09-27       113
# 7        Unidas  2000.0    108% do CDI 2019-09-20       108
# 8        Unidas   150.0    CDI + 1,40% 2017-11-29      1.40
# 9    Auto Ricci   300.0    CDI + 2,10% 2017-06-22      2.10
# 10  Unidas S.A.    70.0    CDI + 3,00% 2016-06-20      3.00
# 11  Unidas S.A.   300.0    CDI + 2,70% 2017-04-07      2.70
# 12  Unidas S.A.    80.0    CDI + 1,20% 2017-09-29      1.20
# 13  Unidas S.A.   500.0  117,5% do CDI 2018-03-29     117.5
# 14  Unidas S.A.   150.0  110,6% do CDI 2018-09-15     110.6
# 15  Unidas S.A.  1000.0  107,9% do CDI 2019-04-10     107.9
# 16  Unidas S.A.   200.0  109,7% do CDI 2019-11-18     109.7
# 17  Unidas S.A.     4.0    CDI + 2,20% 2017-03-03      2.20

# %%
df_unidas_cdi = pd.merge(df_unidas, cdi, left_on= 'date', right_on= 'Data').drop(['Data', 'Financeiro (R$)', 'Operações','Média', 'Mediana','Moda','Desvio padrão','Índice de curtose', 'Date' ], axis=1)

# %%
def custo_div(rate, true_rate, taxa):
    
    if rate.startswith('CDI'):
        return (true_rate/100)+(taxa/100)
    else:
        return (true_rate/100)*(taxa/100)

# %%
def custo_div_row(row):
    
    if str(row['rate']).startswith('CDI'):
        return (float(row['true_rate'])/100)+(float(row['Taxa (% a.a.)'])/100)
    else:
        return (float(row['true_rate'])/100)*(float(row['Taxa (% a.a.)'])/100)

# %%
df_unidas_cdi.head()
# Out:
#      name  amount         rate       date true_rate  Taxa (% a.a.)  \
# 0  Unidas   100.0  CDI + 1,75% 2013-10-29      1.75           9.40
# 1  Unidas   150.0  CDI + 2,20% 2017-06-23      2.20          10.15
# 2  Unidas   250.0  CDI + 1,40% 2017-08-28      1.40           9.15
# 3  Unidas   100.0  CDI + 1,20% 2017-11-17      1.20           7.40
# 4  Unidas   411.4  CDI + 1,40% 2018-02-19      1.40           6.65
#
#   Fator diário  custo_div  custo_div_2
# 0   1,00035657     0.1115        11.15
# 1   1,00038370     0.1235        12.35
# 2   1,00034749     0.1055        10.55
# 3   1,00028333     0.0860         8.60
# 4   1,00025552     0.0805         8.05

# %%
custo_div('CDI + 1,75%',1.75, 9.40)
# Out:
# 0.1115

# %%
df_unidas_cdi.apply(custo_div_row, axis=1)
# Out:
# 0     0.111500
# 1     0.123500
# 2     0.105500
# 3     0.086000
# 4     0.080500
# 5     0.076160
# 6     0.072320
# 7     0.058320
# 8     0.088000
# 9     0.122500
# 10    0.171500
# 11    0.148500
# 12    0.093500
# 13    0.075200
# 14    0.069056
# 15    0.053753
# 16    0.143500
# dtype: float64

# %%
df_unidas_cdi['custo_div'] = df_unidas_cdi.apply(
    lambda x: custo_div(
        str(x['rate']), 
        float(x['true_rate']), 
        float(x['Taxa (% a.a.)'])
    ), axis=1)

# %%
df_unidas_cdi['custo_div_2'] = df_unidas_cdi['custo_div']*100

# %%
df_unidas_cdi
# Out:
#            name  amount           rate       date true_rate  Taxa (% a.a.)  \
# 0        Unidas   100.0    CDI + 1,75% 2013-10-29      1.75           9.40
# 1        Unidas   150.0    CDI + 2,20% 2017-06-23      2.20          10.15
# 2        Unidas   250.0    CDI + 1,40% 2017-08-28      1.40           9.15
# 3        Unidas   100.0    CDI + 1,20% 2017-11-17      1.20           7.40
# 4        Unidas   411.4    CDI + 1,40% 2018-02-19      1.40           6.65
# 5        Unidas   350.0    119% do CDI 2018-04-27       119           6.40
# 6        Unidas   400.0    113% do CDI 2018-09-27       113           6.40
# 7        Unidas  2000.0    108% do CDI 2019-09-20       108           5.40
# 8        Unidas   150.0    CDI + 1,40% 2017-11-29      1.40           7.40
# 9    Auto Ricci   300.0    CDI + 2,10% 2017-06-22      2.10          10.15
# 10  Unidas S.A.    70.0    CDI + 3,00% 2016-06-20      3.00          14.15
# 11  Unidas S.A.   300.0    CDI + 2,70% 2017-04-07      2.70          12.15
# 12  Unidas S.A.    80.0    CDI + 1,20% 2017-09-29      1.20           8.15
# 13  Unidas S.A.   500.0  117,5% do CDI 2018-03-29     117.5           6.40
# 14  Unidas S.A.  1000.0  107,9% do CDI 2019-04-10     107.9           6.40
# 15  Unidas S.A.   200.0  109,7% do CDI 2019-11-18     109.7           4.90
# 16  Unidas S.A.     4.0    CDI + 2,20% 2017-03-03      2.20          12.15
#
#    Fator diário  custo_div  custo_div_2
# 0    1,00035657   0.111500      11.1500
# 1    1,00038370   0.123500      12.3500
# 2    1,00034749   0.105500      10.5500
# 3    1,00028333   0.086000       8.6000
# 4    1,00025552   0.080500       8.0500
# 5    1,00024620   0.076160       7.6160
# 6    1,00024620   0.072320       7.2320
# 7    1,00020872   0.058320       5.8320
# 8    1,00028333   0.088000       8.8000
# 9    1,00038370   0.122500      12.2500
# 10   1,00052531   0.171500      17.1500
# 11   1,00045513   0.148500      14.8500
# 12   1,00031096   0.093500       9.3500
# 13   1,00024620   0.075200       7.5200
# 14   1,00024620   0.069056       6.9056
# 15   1,00018985   0.053753       5.3753
# 16   1,00045513   0.143500      14.3500

# %%
df['amount'] = pd.to_numeric(df['amount'].apply(lambda x: x.replace('.','').replace(',', '.')))

# %%
df
# Out:
#                                   name  amount         rate       date
# 0             Localiza Rent a Car S.A.   500.0  111,50% CDI 2016-12-12
# 1             Localiza Rent a Car S.A.   700.0  107,25% CDI 2017-05-15
# 2             Localiza Rent a Car S.A.   868.9  109,35% CDI 2017-12-15
# 3             Localiza Rent a Car S.A.   216.1  111,30% CDI 2017-12-15
# 4             Localiza Rent a Car S.A.   200.0  107,90% CDI 2018-09-18
# 5             Localiza Rent a Car S.A.   800.0  112,32% CDI 2018-09-18
# 6             Localiza Rent a Car S.A.  1000.0  107,25% CDI 2019-04-15
# 7             Localiza Rent a Car S.A.  1000.0  CDI + 1,05% 2019-11-29
# 8                  Localiza Fleet S.A.   300.0  112,00% CDI 2018-07-18
# 9                  Localiza Fleet S.A.   400.0  110,40% CDI 2018-12-21
# 10                 Localiza Fleet S.A.   300.0  109,00% CDI 2019-07-29
# 11                 Localiza Fleet S.A.   999.9  CDI + 1,00% 2020-02-12
# 12            Localiza Rent a Car S.A.   500.0  108,00% CDI 2019-09-24
# 13  Rental Brasil Adm. E Participações   370.0   99,00% CDI 2018-02-26

# %%
# agora vamos usar o merge para trazer as informações de cdi para o df da localiza:
df_localiza=pd.merge(df, cdi, left_on= 'date', right_on= 'Data').drop(['Data', 'Financeiro (R$)', 'Operações','Média','Mediana', 'Moda','Desvio padrão', 'Índice de curtose', 'Date'], axis=1)

# %%
df_localiza
# Out:
#                                   name  amount         rate       date  \
# 0             Localiza Rent a Car S.A.   500.0  111,50% CDI 2016-12-12
# 1             Localiza Rent a Car S.A.   700.0  107,25% CDI 2017-05-15
# 2             Localiza Rent a Car S.A.   868.9  109,35% CDI 2017-12-15
# 3             Localiza Rent a Car S.A.   216.1  111,30% CDI 2017-12-15
# 4             Localiza Rent a Car S.A.   200.0  107,90% CDI 2018-09-18
# 5             Localiza Rent a Car S.A.   800.0  112,32% CDI 2018-09-18
# 6             Localiza Rent a Car S.A.  1000.0  107,25% CDI 2019-04-15
# 7             Localiza Rent a Car S.A.  1000.0  CDI + 1,05% 2019-11-29
# 8                  Localiza Fleet S.A.   300.0  112,00% CDI 2018-07-18
# 9                  Localiza Fleet S.A.   400.0  110,40% CDI 2018-12-21
# 10                 Localiza Fleet S.A.   300.0  109,00% CDI 2019-07-29
# 11                 Localiza Fleet S.A.   999.9  CDI + 1,00% 2020-02-12
# 12            Localiza Rent a Car S.A.   500.0  108,00% CDI 2019-09-24
# 13  Rental Brasil Adm. E Participações   370.0   99,00% CDI 2018-02-26
#
#     Taxa (% a.a.) Fator diário
# 0           13.65   1,00050788
# 1           11.15   1,00041957
# 2            6.90   1,00026481
# 3            6.90   1,00026481
# 4            6.40   1,00024620
# 5            6.40   1,00024620
# 6            6.40   1,00024620
# 7            4.90   1,00018985
# 8            6.40   1,00024620
# 9            6.40   1,00024620
# 10           6.40   1,00024620
# 11           4.15   1,00016137
# 12           5.40   1,00020872
# 13           6.65   1,00025552

# %%
df_localiza['true_rate'] = df_localiza['rate'].apply(parse_cdi)

# %%
df_localiza['custo_div'] = df_localiza.apply(
    lambda x: custo_div(
        str(x['rate']), 
        float(x['true_rate']), 
        float(x['Taxa (% a.a.)'])
    ), axis=1)

# %%
df_localiza
# Out:
#                                   name  amount         rate       date  \
# 0             Localiza Rent a Car S.A.   500.0  111,50% CDI 2016-12-12
# 1             Localiza Rent a Car S.A.   700.0  107,25% CDI 2017-05-15
# 2             Localiza Rent a Car S.A.   868.9  109,35% CDI 2017-12-15
# 3             Localiza Rent a Car S.A.   216.1  111,30% CDI 2017-12-15
# 4             Localiza Rent a Car S.A.   200.0  107,90% CDI 2018-09-18
# 5             Localiza Rent a Car S.A.   800.0  112,32% CDI 2018-09-18
# 6             Localiza Rent a Car S.A.  1000.0  107,25% CDI 2019-04-15
# 7             Localiza Rent a Car S.A.  1000.0  CDI + 1,05% 2019-11-29
# 8                  Localiza Fleet S.A.   300.0  112,00% CDI 2018-07-18
# 9                  Localiza Fleet S.A.   400.0  110,40% CDI 2018-12-21
# 10                 Localiza Fleet S.A.   300.0  109,00% CDI 2019-07-29
# 11                 Localiza Fleet S.A.   999.9  CDI + 1,00% 2020-02-12
# 12            Localiza Rent a Car S.A.   500.0  108,00% CDI 2019-09-24
# 13  Rental Brasil Adm. E Participações   370.0   99,00% CDI 2018-02-26
#
#     Taxa (% a.a.) Fator diário true_rate  custo_div
# 0           13.65   1,00050788    111.50   0.152198
# 1           11.15   1,00041957    107.25   0.119584
# 2            6.90   1,00026481    109.35   0.075452
# 3            6.90   1,00026481    111.30   0.076797
# 4            6.40   1,00024620    107.90   0.069056
# 5            6.40   1,00024620    112.32   0.071885
# 6            6.40   1,00024620    107.25   0.068640
# 7            4.90   1,00018985      1.05   0.059500
# 8            6.40   1,00024620    112.00   0.071680
# 9            6.40   1,00024620    110.40   0.070656
# 10           6.40   1,00024620    109.00   0.069760
# 11           4.15   1,00016137      1.00   0.051500
# 12           5.40   1,00020872    108.00   0.058320
# 13           6.65   1,00025552     99.00   0.065835

# %%
df_localiza['custo_div_2'] = df_localiza['custo_div']*100

# %%
df_localiza
# Out:
#                                   name  amount         rate       date  \
# 0             Localiza Rent a Car S.A.   500.0  111,50% CDI 2016-12-12
# 1             Localiza Rent a Car S.A.   700.0  107,25% CDI 2017-05-15
# 2             Localiza Rent a Car S.A.   868.9  109,35% CDI 2017-12-15
# 3             Localiza Rent a Car S.A.   216.1  111,30% CDI 2017-12-15
# 4             Localiza Rent a Car S.A.   200.0  107,90% CDI 2018-09-18
# 5             Localiza Rent a Car S.A.   800.0  112,32% CDI 2018-09-18
# 6             Localiza Rent a Car S.A.  1000.0  107,25% CDI 2019-04-15
# 7             Localiza Rent a Car S.A.  1000.0  CDI + 1,05% 2019-11-29
# 8                  Localiza Fleet S.A.   300.0  112,00% CDI 2018-07-18
# 9                  Localiza Fleet S.A.   400.0  110,40% CDI 2018-12-21
# 10                 Localiza Fleet S.A.   300.0  109,00% CDI 2019-07-29
# 11                 Localiza Fleet S.A.   999.9  CDI + 1,00% 2020-02-12
# 12            Localiza Rent a Car S.A.   500.0  108,00% CDI 2019-09-24
# 13  Rental Brasil Adm. E Participações   370.0   99,00% CDI 2018-02-26
#
#     Taxa (% a.a.) Fator diário true_rate  custo_div  custo_div_2
# 0           13.65   1,00050788    111.50   0.152198    15.219750
# 1           11.15   1,00041957    107.25   0.119584    11.958375
# 2            6.90   1,00026481    109.35   0.075452     7.545150
# 3            6.90   1,00026481    111.30   0.076797     7.679700
# 4            6.40   1,00024620    107.90   0.069056     6.905600
# 5            6.40   1,00024620    112.32   0.071885     7.188480
# 6            6.40   1,00024620    107.25   0.068640     6.864000
# 7            4.90   1,00018985      1.05   0.059500     5.950000
# 8            6.40   1,00024620    112.00   0.071680     7.168000
# 9            6.40   1,00024620    110.40   0.070656     7.065600
# 10           6.40   1,00024620    109.00   0.069760     6.976000
# 11           4.15   1,00016137      1.00   0.051500     5.150000
# 12           5.40   1,00020872    108.00   0.058320     5.832000
# 13           6.65   1,00025552     99.00   0.065835     6.583500

# %%
df_locadoras = pd.DataFrame(df_unidas_cdi).append(df_localiza)

# %%
df_locadoras['adj_name'] = df_locadoras['name'].str.split(' ', ).apply(lambda x: x[0])

# %%
# agora que temos os dados das duas locadoras juntos, vamos tentar plotar o gráfico:
d = {
    'Localiza': 'green',
    'Unidas': 'blue'
}

# %%
df_locadoras.plot.scatter(
    x='date',
    y='custo_div_2',
    alpha=0.4,
    figsize=(10,8), 
    s= df_locadoras['amount'] *2, 
    c=df_locadoras['adj_name'].apply(lambda x: d.get(x, 'grey'))
)

# %%
df_locadoras.plot.scatter(
    x='amount',
    y='custo_div_2',
    alpha=0.4,
    figsize=(10,8), 
    s= df_locadoras['amount'] *2, 
    c=df_locadoras['adj_name'].apply(lambda x: d.get(x, 'grey'))
)

# %%
# agora só faltam os dados da Movida:
driver= webdriver.Chrome(executable_path='./chromedriver')
driver.get("https://ri.movida.com.br/385949-2/")

# %%
table = driver.find_element_by_tag_name('table')

# %%
body = table.find_element_by_tag_name('tbody')

# %%
rows= body.find_elements_by_tag_name('tr')

# %%
data_movida = []

for row in rows:
    cells = row.find_elements_by_tag_name('td')
    if len(cells) >= 8:
        # linha cheia
        nome= cells[1].get_attribute('innerHTML')
        data_emissao = cells[2].get_attribute('innerHTML')
        volume = cells[6].get_attribute('innerHTML')
        taxa = cells[7].get_attribute('innerHTML')
        
        d = {'nome': nome , 'data_emissao': data_emissao, 'volume': volume, 'taxa': taxa}
    else: 
        # linha contém informaçoes da mesma emissão que a anterior
        nome = None
        data_emissao = None
        volume = cells[3].get_attribute('innerHTML')
        taxa = cells[4].get_attribute('innerHTML')
        
        d = {'nome': nome , 'data_emissao': data_emissao, 'volume': volume, 'taxa': taxa}
    data_movida.append(d)

# %%
movida = pd.DataFrame(data_movida)

# %%
movida = movida.fillna(method='ffill')
# Out:
#                                nome data_emissao         volume   taxa
# 0         Movida Participações S.A.   15/07/2017  R$150 milhões  1,55%
# 1         Movida Participações S.A.   15/07/2017  R$250 milhões  2,70%
# 2   Movida Locação de Veículos S.A.   29/03/2018  R$250 milhões  2,00%
# 3         Movida Participações S.A.   07/06/2018  R$138 milhões  1,60%
# 4         Movida Participações S.A.   07/06/2018  R$181 milhões  2,20%
# 5         Movida Participações S.A.   07/06/2018  R$130 milhões  1,90%
# 6   Movida Locação de Veículos S.A.   10/10/2018  R$100 milhões  1,80%
# 7         Movida Participações S.A.   07/12/2018  R$214 milhões  1,85%
# 8         Movida Participações S.A.   07/12/2018  R$138 milhões  2,05%
# 9         Movida Participações S.A.   07/12/2018  R$247 milhões  2,05%
# 10  Movida Locação de Veículos S.A.   24/06/2019  R$250 milhões  1,60%
# 11        Movida Participações S.A.   27/06/2019  R$250 milhões  1,25%
# 12        Movida Participações S.A.   27/06/2019  R$166 milhões  1,60%
# 13        Movida Participações S.A.   27/06/2019  R$284 milhões  2,05%
